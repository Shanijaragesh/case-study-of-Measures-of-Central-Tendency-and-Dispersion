# %%
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import numpy

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# ## 1. Find out how many males and females participated in the test.

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# .No of males and females participated in the test are 482 males and 518 females

# %%
df.groupby('gender')['test preparation course'].value_counts()
# Out:
# gender  test preparation course
# female  none                       334
#         completed                  184
# male    none                       308
#         completed                  174
# Name: test preparation course, dtype: int64

# %% [markdown]
# .From the 518 females only 184 completed the test preparation course and 334 coudn't complete
# From the total of 482 males only 174 completed the test preparation course and 308 couldn't complete

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
df.groupby('gender')['parental level of education'].value_counts()
# Out:
# gender  parental level of education
# female  some college                   118
#         associate's degree             116
#         high school                     94
#         some high school                91
#         bachelor's degree               63
#         master's degree                 36
# male    some college                   108
#         associate's degree             106
#         high school                    102
#         some high school                88
#         bachelor's degree               55
#         master's degree                 23
# Name: parental level of education, dtype: int64

# %% [markdown]
# .parental level education in males and females

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# parental level of education as total

# %% [markdown]
# ## 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
df.groupby('gender').mean()
# Out:
#         math score  reading score  writing score
# gender
# female   63.376448      72.590734      72.467181
# male     68.821577      65.545643      63.446058

# %% [markdown]
# Female students scored most for reading and writing .Male students sored most in maths

# %%
df.groupby('test preparation course').mean()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                  69.96648      74.175978      74.684358
# none                       63.78972      66.417445      64.457944

# %% [markdown]
# .Test preparation course completed students score most than those who have not completed

# %%
df.groupby(['gender','test preparation course']).mean()
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                 67.108696      77.375000      78.793478
#        none                      61.320359      69.955090      68.982036
# male   completed                 72.988506      70.793103      70.339080
#        none                      66.467532      62.581169      59.551948

# %% [markdown]
# ## 4. What do you think about the scoring variation for math, reading and writing
# based on
# ● Gender
# ● Test preparation course

# %%
df.groupby('gender').var()
# Out:
#         math score  reading score  writing score
# gender
# female  256.958593     207.677438     220.369327
# male    211.889097     200.211010     202.413924

# %% [markdown]
# when comparing the variation in maths,reading and writing score female has more variation than males

# %%
df.groupby('test preparation course').var()
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                210.884027     183.265864     175.202612
# none                     246.668662     213.419851     226.251739

# %% [markdown]
# . when comparing the variationon test preparation course completed is less than not completed ones

# %%
df.groupby(['gender','test preparation course']).var()
# Out:
#                                 math score  reading score  writing score
# gender test preparation course
# female completed                208.173913     161.175546     149.836897
#        none                     272.602767     214.241220     225.495172
# male   completed                197.098133     185.297987     166.098233
#        none                     205.513600     184.843553     181.394687

# %% [markdown]
# .we took both the parameters together .Results are same but there is slight difference in number

# %% [markdown]
# ## 5. The management needs your help to give bonus points to the top 25% of
# students based on their math score, so how will you help the management
# to achieve this.

# %%
df1 = df.sort_values(by=['math score'],ascending=False)
df1
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 2    female        group B            some high school  free/reduced
# 51   female        group C            some high school  free/reduced
# 3    female        group B                some college      standard
# 1    female        group B                 high school  free/reduced
# 0    female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
d=df1.quantile(0.75)
d.head()
# Out:
# math score       77.00
# reading score    79.25
# writing score    79.00
# Name: 0.75, dtype: float64

# %%
df1['math score'] >=77
# Out:
# 999     True
# 996     True
# 515     True
# 517     True
# 516     True
#        ...
# 2      False
# 51     False
# 3      False
# 1      False
# 0      False
# Name: math score, Length: 1000, dtype: bool

# %%
df1[df1['math score']>=d['math score']]
#df1[df1['math score']>=77 *alternative code
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 851    male        group D                some college      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 421  female        group C                some college  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# .shows the index of the students who scored top 25% in math score

# %%
df1.loc[(df1['math score']) >=(d['math score'])]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999    male        group E           bachelor's degree      standard
# 996    male        group A                some college      standard
# 515  female        group E                some college      standard
# 517  female        group E          associate's degree      standard
# 516  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 851    male        group D                some college      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 421  female        group C                some college  free/reduced
# 414  female        group A                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.nlargest(250,'math score')
#df1.nlargest(250,'math score') * alternative code
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
